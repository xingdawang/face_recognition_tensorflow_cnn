# %%
import pathlib, os, shutil, cv2
import numpy as np

"""
    source: source images directory
    destination: destination images directory
    angle: rotate angle
    cascadeClassifier: default face detection config,
        link: https://github.com/opencv/opencv/blob/master/data/haarcascades/haarcascade_frontalface_default.xml
"""
def extract_image(source, destination, angle, cascadeClassifier, cropped=True):
    vidcap = cv2.VideoCapture(source)

    success, image = vidcap.read()
    count, failed_count = 0, 0
    success = True
    while success:
        file_name = "frame%d.jpg" % count
        file = os.path.join(destination, file_name)
        raw_portrait_image = _rotate_image(image, angle)
        
        # whether face detection needed or not
        if cropped == True:
            portrait_image = detect_crop_face(raw_portrait_image, cascadeClassifier)
            if portrait_image is None:
                failed_count += 1
                print('photo generated failed at {}'.format(count))
            else:
                cv2.imwrite(file, portrait_image)     # save frame as JPEG file
        else:
            cv2.imwrite(file, raw_portrait_image)
        
        success, image = vidcap.read() 
        if count % 100 == 0:
            print("Generated: {} photos in {}".format(count, destination))
        count += 1
    print('Total generated {} photos'.format(count - failed_count))
    
def _rotate_image(image, angle):
    # rotate image some degree
    height, width = image.shape[:2]
    image_center = (width/2, height/2)
    rotation_mat = cv2.getRotationMatrix2D(image_center, angle, 1.)

    # rotation calculates the cos and sin, taking absolutes of those.
    abs_cos = abs(rotation_mat[0,0]) 
    abs_sin = abs(rotation_mat[0,1])

    # find the new width and height bounds
    bound_w = int(height * abs_sin + width * abs_cos)
    bound_h = int(height * abs_cos + width * abs_sin)

    # subtract old image center (bringing image back to origo) and adding the new image center coordinates
    rotation_mat[0, 2] += bound_w/2 - image_center[0]
    rotation_mat[1, 2] += bound_h/2 - image_center[1]

    rotated_image = cv2.warpAffine(image, rotation_mat, (bound_w, bound_h))
    return rotated_image

"""
    Detect face in image, extract and return the face image.
    image: the raw photo which contains the face
    faceCascade: face cascade xml config file,
        link: https://github.com/opencv/opencv/blob/master/data/haarcascades/haarcascade_frontalface_default.xml
"""
def detect_crop_face(image, faceCascade):
    face_cascade = cv2.CascadeClassifier(faceCascade)
    gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
    faces = face_cascade.detectMultiScale(gray, 1.3, 5)
    if faces == ():
        return None
    else:
        for (x,y,w,h) in faces:
            return image[y:y+h, x:x+w]

# %%
def img_to_array(source_folder_path, y_label, target_image_width, target_image_height, RGB=True):
    if RGB == True:
        channels = 3
    else:
        channels = 1
    total_item = len(os.listdir(source_folder_path))
    counter = 1
    X = np.empty((1, target_image_width * target_image_height * channels))
    y = np.full((total_item, 1), y_label)
    for file_name in os.listdir(source_folder_path):
        file = os.path.join(source_folder_path, file_name)
        image = cv2.imread(file)
        reshaped_image = cv2.resize(image, (target_image_width, target_image_height))
        reshaped_image_1d = reshaped_image.reshape(1, -1)
        if counter == 1:
            X = reshaped_image_1d
        else:
            X = np.concatenate((X, reshaped_image_1d))
        counter += 1
    return X, y

# %%
import numpy as np
import os, cv2

source_folder_path='/Users/xingdawang/Movies/xingda/'
y_label = 0
target_image_width, target_image_height = 150, 150
xingda_X, xingda_y = img_to_array(
    source_folder_path = source_folder_path,
    y_label = y_label,
    target_image_width = target_image_width,
    target_image_height = target_image_height)

# %%
source_folder_path='/Users/xingdawang/Movies/julie/'
y_label = 1
target_image_width, target_image_height = 150, 150
julie_X, julie_y = img_to_array(
    source_folder_path = source_folder_path,
    y_label = y_label,
    target_image_width = target_image_width,
    target_image_height = target_image_height)

# %%
source_folder_path='/Users/xingdawang/Movies/melanie/'
y_label = 2
target_image_width, target_image_height = 150, 150
melanie_X, melanie_y = img_to_array(
    source_folder_path = source_folder_path,
    y_label = y_label,
    target_image_width = target_image_width,
    target_image_height = target_image_height)

# %%
# Concatenate result X & y
X_input = np.concatenate((np.concatenate((xingda_X, julie_X)), melanie_X))
y_input = np.concatenate((np.concatenate((xingda_y, julie_y)), melanie_y))

# Reset and scale X & y shape
X_input_raw = X_input / 255.
y_input_raw = y_input.reshape(-1)

# shuffle X & y with predictable result
index = np.random.choice(np.arange(len(y_input_raw)), len(y_input_raw), replace=False)
X_input = X_input_raw[index]
y_input = y_input_raw[index]

# %%
# X_input = X_input.astype(np.float32) / 255.

X_train, X_test = X_input[:250], X_input[250:300]
y_train, y_test = y_input[:250], y_input[250:300]
X_train, X_valid = X_train[:200], X_train[200:250]
y_train, y_valid = y_train[:200], y_train[200:259]

# %%
print("Train X shape:\t\t", X_train.shape)
print("Validation X shape:\t", X_valid.shape)
print("Test X shape:\t\t", X_test.shape)
print("Train y shape:\t\t", y_train.shape)
print("Validation y shape:\t", y_valid.shape)
print("Test y shape:\t\t", y_valid.shape)
# Out:
# Train X shape:		 (200, 67500)
# Validation X shape:	 (50, 67500)
# Test X shape:		 (50, 67500)
# Train y shape:		 (200,)
# Validation y shape:	 (50,)
# Test y shape:		 (50,)

# %%
import numpy as np
import tensorflow as tf

width, height = 150, 150
n_outputs = 3
channels = 3
n_inputs = height * width * channels
tf.reset_default_graph()

with tf.name_scope("inputs"):
    X = tf.placeholder(tf.float32, shape=[None, n_inputs], name = "X")
    X_reshaped = tf.reshape(X, shape=[-1, height, width, channels])
    y = tf.placeholder(tf.int32, shape = [None, n_outputs], name = "y")
    y_reshaped = tf.argmax(y, dimension=1)
    
with tf.name_scope('conv32_layer'):
#     conv shape: [mini-batch size, height, width, channels]
    conv32_1 = tf.layers.conv2d(inputs=X_reshaped, filters=32, kernel_size=[3, 3], padding='same', activation=tf.nn.relu, name='conv32_1')
    conv32_2 = tf.layers.conv2d(inputs=conv32_1, filters=32, kernel_size=[3, 3], activation=tf.nn.relu)
    max_pool32_1 = tf.layers.max_pooling2d(conv32_2, pool_size=[2, 2], strides=2)
    dropout32_1 = tf.layers.dropout(inputs=max_pool32_1, rate=0.25)
    
with tf.name_scope('conv64_layer'):
    conv64_1 = tf.layers.conv2d(inputs=dropout32_1, filters=64, kernel_size=[3, 3], activation=tf.nn.relu)
    conv64_2 = tf.layers.conv2d(inputs=conv64_1, filters=64, kernel_size=[3, 3], activation=tf.nn.relu)
    max_pool64_1 = tf.layers.max_pooling2d(conv64_2, pool_size=[2, 2], strides=2)
    dropout64_1 = tf.layers.dropout(inputs=max_pool64_1, rate=0.25)

with tf.name_scope('conv128_layer'):
    conv128_1 = tf.layers.conv2d(inputs=dropout64_1, filters=128, kernel_size=[3, 3], activation=tf.nn.relu)
    max_pool128_1 = tf.layers.max_pooling2d(conv128_1, pool_size=[2, 2], strides=2)
    dropout128_1 = tf.layers.dropout(inputs=max_pool128_1, rate=0.25)
    conv128_2 = tf.layers.conv2d(inputs=dropout128_1, filters=128, kernel_size=[3, 3], activation=tf.nn.relu)
    max_pool128_2 = tf.layers.max_pooling2d(conv128_2, pool_size=[2, 2], strides=2)
    dropout128_2 = tf.layers.dropout(inputs=max_pool128_2, rate=0.25)
    
with tf.name_scope('conv256_layer'):
    conv256_1 = tf.layers.conv2d(inputs=dropout128_2, filters=256, kernel_size=[3, 3], activation=tf.nn.relu)
    max_pool256_1 = tf.layers.max_pooling2d(conv256_1, pool_size=[2, 2], strides=2)
    dropout256_1 = tf.layers.dropout(inputs=max_pool256_1, rate=0.25)

with tf.name_scope("outputs_layer"):
    outputs_layer_reshaped = tf.layers.flatten(dropout256_1)
    outputs_layer512_1 = tf.layers.dense(outputs_layer_reshaped, 512, activation=tf.nn.relu)
    outputs_dropout_1 = tf.layers.dropout(inputs=outputs_layer512_1, rate=0.5, name='output')
    logits = tf.layers.dense(outputs_dropout_1, n_outputs, activation=tf.nn.relu)
    Y_proba = tf.nn.softmax(logits, name="Y_proba")

with tf.name_scope("train"):
    xentropy = tf.nn.sparse_softmax_cross_entropy_with_logits(logits=logits, labels=y_reshaped)
    loss = tf.reduce_mean(xentropy)
    optimizer = tf.train.AdamOptimizer()
    training_op = optimizer.minimize(loss)

with tf.name_scope("eval"):
    correct = tf.nn.in_top_k(logits, y_reshaped, 1)
    accuracy = tf.reduce_mean(tf.cast(correct, tf.float32))

with tf.name_scope("init_and_save"):
    init = tf.global_variables_initializer()
    saver = tf.train.Saver()

# %%
n_epoch = 10
batch_size = 10

def shuffle_batch(X, y, batch_size):
    rnd_idx = np.random.permutation(len(X))
    n_batches = len(X) // batch_size
    for batch_idx in np.array_split(rnd_idx, n_batches):
        X_batch, y_batch = X[batch_idx], y[batch_idx]
        yield X_batch, y_batch

        
with tf.Session() as sess:
    init.run()
    for epoch in range(n_epoch):
        for X_batch, y_batch in shuffle_batch(X_train, y_train, batch_size):
            sess.run(training_op, feed_dict={X: X_batch, y: y_batch})
        acc_batch = accuracy.eval(feed_dict={X: X_batch, y: y_batch})
        acc_test = accuracy.eval(feed_dict={X: X_test, y: y_test})
        print(epoch, "Last batch accuracy:", acc_batch, "Test accuracy:", acc_test)

        save_path = saver.save(sess, "./test")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-234-ffe29193e9dd> in <module>
#      14     for epoch in range(n_epoch):
#      15         for X_batch, y_batch in shuffle_batch(X_train, y_train, batch_size):
# ---> 16             sess.run(training_op, feed_dict={X: X_batch, y: y_batch})
#      17         acc_batch = accuracy.eval(feed_dict={X: X_batch, y: y_batch})
#      18         acc_test = accuracy.eval(feed_dict={X: X_test, y: y_test})
#
# /anaconda3/lib/python3.6/site-packages/tensorflow/python/client/session.py in run(self, fetches, feed_dict, options, run_metadata)
#     927     try:
#     928       result = self._run(None, fetches, feed_dict, options_ptr,
# --> 929                          run_metadata_ptr)
#     930       if run_metadata:
#     931         proto_data = tf_session.TF_GetBuffer(run_metadata_ptr)
#
# /anaconda3/lib/python3.6/site-packages/tensorflow/python/client/session.py in _run(self, handle, fetches, feed_dict, options, run_metadata)
#    1126                              'which has shape %r' %
#    1127                              (np_val.shape, subfeed_t.name,
# -> 1128                               str(subfeed_t.get_shape())))
#    1129           if not self.graph.is_feedable(subfeed_t):
#    1130             raise ValueError('Tensor %s may not be fed.' % subfeed_t)
#
# ValueError: Cannot feed value of shape (10,) for Tensor 'inputs/y:0', which has shape '(?, 3)'

# %%
import matplotlib.pyplot as plt
# plt.imshow(X_input[20].reshape(150, 150, 3))
y_input[20]
# Out:
# 1

# %%
import tensorflow as tf

sess=tf.Session()    
#First let's load meta graph and restore weights
saver = tf.train.import_meta_graph('test.meta')
saver.restore(sess, tf.train.latest_checkpoint('./'))


# Now, let's access and create placeholders variables and
# create feed-dict to feed new data
graph = tf.get_default_graph()
# Check tensor name
# [n.name for n in tf.get_default_graph().as_graph_def().node]
X_test = graph.get_tensor_by_name("inputs/X:0")
y_test = graph.get_tensor_by_name("inputs/y:0")

#Now, access the op that you want to run. 
Y_proba = graph.get_tensor_by_name("outputs_layer/Y_proba_1:0")

result = sess.run(
    Y_proba,
    feed_dict = {
        X: X_input[20].reshape(1, -1),
        y: y_input[20].reshape(1,-1)})
print(result)
# Out:
# INFO:tensorflow:Restoring parameters from ./test
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-229-be2118e92b64> in <module>
#      22     feed_dict = {
#      23         X: X_input[20].reshape(1, -1),
# ---> 24         y: y_input[20].reshape(1,-1)})
#      25 print(result)
#
# /anaconda3/lib/python3.6/site-packages/tensorflow/python/client/session.py in run(self, fetches, feed_dict, options, run_metadata)
#     927     try:
#     928       result = self._run(None, fetches, feed_dict, options_ptr,
# --> 929                          run_metadata_ptr)
#     930       if run_metadata:
#     931         proto_data = tf_session.TF_GetBuffer(run_metadata_ptr)
#
# /anaconda3/lib/python3.6/site-packages/tensorflow/python/client/session.py in _run(self, handle, fetches, feed_dict, options, run_metadata)
#    1126                              'which has shape %r' %
#    1127                              (np_val.shape, subfeed_t.name,
# -> 1128                               str(subfeed_t.get_shape())))
#    1129           if not self.graph.is_feedable(subfeed_t):
#    1130             raise ValueError('Tensor %s may not be fed.' % subfeed_t)
#
# ValueError: Cannot feed value of shape (1, 1) for Tensor 'inputs/y:0', which has shape '(?,)'

# %%
# Out:
# ['inputs/X',
#  'inputs/Reshape/shape',
#  'inputs/Reshape',
#  'inputs/y',
#  'conv32_1/kernel/Initializer/random_uniform/shape',
#  'conv32_1/kernel/Initializer/random_uniform/min',
#  'conv32_1/kernel/Initializer/random_uniform/max',
#  'conv32_1/kernel/Initializer/random_uniform/RandomUniform',
#  'conv32_1/kernel/Initializer/random_uniform/sub',
#  'conv32_1/kernel/Initializer/random_uniform/mul',
#  'conv32_1/kernel/Initializer/random_uniform',
#  'conv32_1/kernel',
#  'conv32_1/kernel/Assign',
#  'conv32_1/kernel/read',
#  'conv32_1/bias/Initializer/zeros',
#  'conv32_1/bias',
#  'conv32_1/bias/Assign',
#  'conv32_1/bias/read',
#  'conv32_layer/conv32_1/dilation_rate',
#  'conv32_layer/conv32_1/Conv2D',
#  'conv32_layer/conv32_1/BiasAdd',
#  'conv32_layer/conv32_1/Relu',
#  'conv2d/kernel/Initializer/random_uniform/shape',
#  'conv2d/kernel/Initializer/random_uniform/min',
#  'conv2d/kernel/Initializer/random_uniform/max',
#  'conv2d/kernel/Initializer/random_uniform/RandomUniform',
#  'conv2d/kernel/Initializer/random_uniform/sub',
#  'conv2d/kernel/Initializer/random_uniform/mul',
#  'conv2d/kernel/Initializer/random_uniform',
#  'conv2d/kernel',
#  'conv2d/kernel/Assign',
#  'conv2d/kernel/read',
#  'conv2d/bias/Initializer/zeros',
#  'conv2d/bias',
#  'conv2d/bias/Assign',
#  'conv2d/bias/read',
#  'conv32_layer/conv2d/dilation_rate',
#  'conv32_layer/conv2d/Conv2D',
#  'conv32_layer/conv2d/BiasAdd',
#  'conv32_layer/conv2d/Relu',
#  'conv32_layer/max_pooling2d/MaxPool',
#  'conv32_layer/dropout/Identity',
#  'conv2d_1/kernel/Initializer/random_uniform/shape',
#  'conv2d_1/kernel/Initializer/random_uniform/min',
#  'conv2d_1/kernel/Initializer/random_uniform/max',
#  'conv2d_1/kernel/Initializer/random_uniform/RandomUniform',
#  'conv2d_1/kernel/Initializer/random_uniform/sub',
#  'conv2d_1/kernel/Initializer/random_uniform/mul',
#  'conv2d_1/kernel/Initializer/random_uniform',
#  'conv2d_1/kernel',
#  'conv2d_1/kernel/Assign',
#  'conv2d_1/kernel/read',
#  'conv2d_1/bias/Initializer/zeros',
#  'conv2d_1/bias',
#  'conv2d_1/bias/Assign',
#  'conv2d_1/bias/read',
#  'conv64_layer/conv2d/dilation_rate',
#  'conv64_layer/conv2d/Conv2D',
#  'conv64_layer/conv2d/BiasAdd',
#  'conv64_layer/conv2d/Relu',
#  'conv2d_2/kernel/Initializer/random_uniform/shape',
#  'conv2d_2/kernel/Initializer/random_uniform/min',
#  'conv2d_2/kernel/Initializer/random_uniform/max',
#  'conv2d_2/kernel/Initializer/random_uniform/RandomUniform',
#  'conv2d_2/kernel/Initializer/random_uniform/sub',
#  'conv2d_2/kernel/Initializer/random_uniform/mul',
#  'conv2d_2/kernel/Initializer/random_uniform',
#  'conv2d_2/kernel',
#  'conv2d_2/kernel/Assign',
#  'conv2d_2/kernel/read',
#  'conv2d_2/bias/Initializer/zeros',
#  'conv2d_2/bias',
#  'conv2d_2/bias/Assign',
#  'conv2d_2/bias/read',
#  'conv64_layer/conv2d_1/dilation_rate',
#  'conv64_layer/conv2d_1/Conv2D',
#  'conv64_layer/conv2d_1/BiasAdd',
#  'conv64_layer/conv2d_1/Relu',
#  'conv64_layer/max_pooling2d/MaxPool',
#  'conv64_layer/dropout/Identity',
#  'conv2d_3/kernel/Initializer/random_uniform/shape',
#  'conv2d_3/kernel/Initializer/random_uniform/min',
#  'conv2d_3/kernel/Initializer/random_uniform/max',
#  'conv2d_3/kernel/Initializer/random_uniform/RandomUniform',
#  'conv2d_3/kernel/Initializer/random_uniform/sub',
#  'conv2d_3/kernel/Initializer/random_uniform/mul',
#  'conv2d_3/kernel/Initializer/random_uniform',
#  'conv2d_3/kernel',
#  'conv2d_3/kernel/Assign',
#  'conv2d_3/kernel/read',
#  'conv2d_3/bias/Initializer/zeros',
#  'conv2d_3/bias',
#  'conv2d_3/bias/Assign',
#  'conv2d_3/bias/read',
#  'conv128_layer/conv2d/dilation_rate',
#  'conv128_layer/conv2d/Conv2D',
#  'conv128_layer/conv2d/BiasAdd',
#  'conv128_layer/conv2d/Relu',
#  'conv128_layer/max_pooling2d/MaxPool',
#  'conv128_layer/dropout/Identity',
#  'conv2d_4/kernel/Initializer/random_uniform/shape',
#  'conv2d_4/kernel/Initializer/random_uniform/min',
#  'conv2d_4/kernel/Initializer/random_uniform/max',
#  'conv2d_4/kernel/Initializer/random_uniform/RandomUniform',
#  'conv2d_4/kernel/Initializer/random_uniform/sub',
#  'conv2d_4/kernel/Initializer/random_uniform/mul',
#  'conv2d_4/kernel/Initializer/random_uniform',
#  'conv2d_4/kernel',
#  'conv2d_4/kernel/Assign',
#  'conv2d_4/kernel/read',
#  'conv2d_4/bias/Initializer/zeros',
#  'conv2d_4/bias',
#  'conv2d_4/bias/Assign',
#  'conv2d_4/bias/read',
#  'conv128_layer/conv2d_1/dilation_rate',
#  'conv128_layer/conv2d_1/Conv2D',
#  'conv128_layer/conv2d_1/BiasAdd',
#  'conv128_layer/conv2d_1/Relu',
#  'conv128_layer/max_pooling2d_1/MaxPool',
#  'conv128_layer/dropout_1/Identity',
#  'conv2d_5/kernel/Initializer/random_uniform/shape',
#  'conv2d_5/kernel/Initializer/random_uniform/min',
#  'conv2d_5/kernel/Initializer/random_uniform/max',
#  'conv2d_5/kernel/Initializer/random_uniform/RandomUniform',
#  'conv2d_5/kernel/Initializer/random_uniform/sub',
#  'conv2d_5/kernel/Initializer/random_uniform/mul',
#  'conv2d_5/kernel/Initializer/random_uniform',
#  'conv2d_5/kernel',
#  'conv2d_5/kernel/Assign',
#  'conv2d_5/kernel/read',
#  'conv2d_5/bias/Initializer/zeros',
#  'conv2d_5/bias',
#  'conv2d_5/bias/Assign',
#  'conv2d_5/bias/read',
#  'conv256_layer/conv2d/dilation_rate',
#  'conv256_layer/conv2d/Conv2D',
#  'conv256_layer/conv2d/BiasAdd',
#  'conv256_layer/conv2d/Relu',
#  'conv256_layer/max_pooling2d/MaxPool',
#  'conv256_layer/dropout/Identity',
#  'outputs_layer/flatten/Shape',
#  'outputs_layer/flatten/strided_slice/stack',
#  'outputs_layer/flatten/strided_slice/stack_1',
#  'outputs_layer/flatten/strided_slice/stack_2',
#  'outputs_layer/flatten/strided_slice',
#  'outputs_layer/flatten/Reshape/shape/1',
#  'outputs_layer/flatten/Reshape/shape',
#  'outputs_layer/flatten/Reshape',
#  'dense/kernel/Initializer/random_uniform/shape',
#  'dense/kernel/Initializer/random_uniform/min',
#  'dense/kernel/Initializer/random_uniform/max',
#  'dense/kernel/Initializer/random_uniform/RandomUniform',
#  'dense/kernel/Initializer/random_uniform/sub',
#  'dense/kernel/Initializer/random_uniform/mul',
#  'dense/kernel/Initializer/random_uniform',
#  'dense/kernel',
#  'dense/kernel/Assign',
#  'dense/kernel/read',
#  'dense/bias/Initializer/zeros',
#  'dense/bias',
#  'dense/bias/Assign',
#  'dense/bias/read',
#  'outputs_layer/dense/MatMul',
#  'outputs_layer/dense/BiasAdd',
#  'outputs_layer/dense/Relu',
#  'outputs_layer/output/Identity',
#  'dense_1/kernel/Initializer/random_uniform/shape',
#  'dense_1/kernel/Initializer/random_uniform/min',
#  'dense_1/kernel/Initializer/random_uniform/max',
#  'dense_1/kernel/Initializer/random_uniform/RandomUniform',
#  'dense_1/kernel/Initializer/random_uniform/sub',
#  'dense_1/kernel/Initializer/random_uniform/mul',
#  'dense_1/kernel/Initializer/random_uniform',
#  'dense_1/kernel',
#  'dense_1/kernel/Assign',
#  'dense_1/kernel/read',
#  'dense_1/bias/Initializer/zeros',
#  'dense_1/bias',
#  'dense_1/bias/Assign',
#  'dense_1/bias/read',
#  'outputs_layer/dense_1/MatMul',
#  'outputs_layer/dense_1/BiasAdd',
#  'outputs_layer/dense_1/Relu',
#  'outputs_layer/Y_proba',
#  'train/SparseSoftmaxCrossEntropyWithLogits/Shape',
#  'train/SparseSoftmaxCrossEntropyWithLogits/SparseSoftmaxCrossEntropyWithLogits',
#  'train/Const',
#  'train/Mean',
#  'train/gradients/Shape',
#  'train/gradients/grad_ys_0',
#  'train/gradients/Fill',
#  'train/gradients/train/Mean_grad/Reshape/shape',
#  'train/gradients/train/Mean_grad/Reshape',
#  'train/gradients/train/Mean_grad/Shape',
#  'train/gradients/train/Mean_grad/Tile',
#  'train/gradients/train/Mean_grad/Shape_1',
#  'train/gradients/train/Mean_grad/Shape_2',
#  'train/gradients/train/Mean_grad/Const',
#  'train/gradients/train/Mean_grad/Prod',
#  'train/gradients/train/Mean_grad/Const_1',
#  'train/gradients/train/Mean_grad/Prod_1',
#  'train/gradients/train/Mean_grad/Maximum/y',
#  'train/gradients/train/Mean_grad/Maximum',
#  'train/gradients/train/Mean_grad/floordiv',
#  'train/gradients/train/Mean_grad/Cast',
#  'train/gradients/train/Mean_grad/truediv',
#  'train/gradients/zeros_like',
#  'train/gradients/train/SparseSoftmaxCrossEntropyWithLogits/SparseSoftmaxCrossEntropyWithLogits_grad/PreventGradient',
#  'train/gradients/train/SparseSoftmaxCrossEntropyWithLogits/SparseSoftmaxCrossEntropyWithLogits_grad/ExpandDims/dim',
#  'train/gradients/train/SparseSoftmaxCrossEntropyWithLogits/SparseSoftmaxCrossEntropyWithLogits_grad/ExpandDims',
#  'train/gradients/train/SparseSoftmaxCrossEntropyWithLogits/SparseSoftmaxCrossEntropyWithLogits_grad/mul',
#  'train/gradients/outputs_layer/dense_1/Relu_grad/ReluGrad',
#  'train/gradients/outputs_layer/dense_1/BiasAdd_grad/BiasAddGrad',
#  'train/gradients/outputs_layer/dense_1/BiasAdd_grad/tuple/group_deps',
#  'train/gradients/outputs_layer/dense_1/BiasAdd_grad/tuple/control_dependency',
#  'train/gradients/outputs_layer/dense_1/BiasAdd_grad/tuple/control_dependency_1',
#  'train/gradients/outputs_layer/dense_1/MatMul_grad/MatMul',
#  'train/gradients/outputs_layer/dense_1/MatMul_grad/MatMul_1',
#  'train/gradients/outputs_layer/dense_1/MatMul_grad/tuple/group_deps',
#  'train/gradients/outputs_layer/dense_1/MatMul_grad/tuple/control_dependency',
#  'train/gradients/outputs_layer/dense_1/MatMul_grad/tuple/control_dependency_1',
#  'train/gradients/outputs_layer/dense/Relu_grad/ReluGrad',
#  'train/gradients/outputs_layer/dense/BiasAdd_grad/BiasAddGrad',
#  'train/gradients/outputs_layer/dense/BiasAdd_grad/tuple/group_deps',
#  'train/gradients/outputs_layer/dense/BiasAdd_grad/tuple/control_dependency',
#  'train/gradients/outputs_layer/dense/BiasAdd_grad/tuple/control_dependency_1',
#  'train/gradients/outputs_layer/dense/MatMul_grad/MatMul',
#  'train/gradients/outputs_layer/dense/MatMul_grad/MatMul_1',
#  'train/gradients/outputs_layer/dense/MatMul_grad/tuple/group_deps',
#  'train/gradients/outputs_layer/dense/MatMul_grad/tuple/control_dependency',
#  'train/gradients/outputs_layer/dense/MatMul_grad/tuple/control_dependency_1',
#  'train/gradients/outputs_layer/flatten/Reshape_grad/Shape',
#  'train/gradients/outputs_layer/flatten/Reshape_grad/Reshape',
#  'train/gradients/conv256_layer/max_pooling2d/MaxPool_grad/MaxPoolGrad',
#  'train/gradients/conv256_layer/conv2d/Relu_grad/ReluGrad',
#  'train/gradients/conv256_layer/conv2d/BiasAdd_grad/BiasAddGrad',
#  'train/gradients/conv256_layer/conv2d/BiasAdd_grad/tuple/group_deps',
#  'train/gradients/conv256_layer/conv2d/BiasAdd_grad/tuple/control_dependency',
#  'train/gradients/conv256_layer/conv2d/BiasAdd_grad/tuple/control_dependency_1',
#  'train/gradients/conv256_layer/conv2d/Conv2D_grad/ShapeN',
#  'train/gradients/conv256_layer/conv2d/Conv2D_grad/Conv2DBackpropInput',
#  'train/gradients/conv256_layer/conv2d/Conv2D_grad/Conv2DBackpropFilter',
#  'train/gradients/conv256_layer/conv2d/Conv2D_grad/tuple/group_deps',
#  'train/gradients/conv256_layer/conv2d/Conv2D_grad/tuple/control_dependency',
#  'train/gradients/conv256_layer/conv2d/Conv2D_grad/tuple/control_dependency_1',
#  'train/gradients/conv128_layer/max_pooling2d_1/MaxPool_grad/MaxPoolGrad',
#  'train/gradients/conv128_layer/conv2d_1/Relu_grad/ReluGrad',
#  'train/gradients/conv128_layer/conv2d_1/BiasAdd_grad/BiasAddGrad',
#  'train/gradients/conv128_layer/conv2d_1/BiasAdd_grad/tuple/group_deps',
#  'train/gradients/conv128_layer/conv2d_1/BiasAdd_grad/tuple/control_dependency',
#  'train/gradients/conv128_layer/conv2d_1/BiasAdd_grad/tuple/control_dependency_1',
#  'train/gradients/conv128_layer/conv2d_1/Conv2D_grad/ShapeN',
#  'train/gradients/conv128_layer/conv2d_1/Conv2D_grad/Conv2DBackpropInput',
#  'train/gradients/conv128_layer/conv2d_1/Conv2D_grad/Conv2DBackpropFilter',
#  'train/gradients/conv128_layer/conv2d_1/Conv2D_grad/tuple/group_deps',
#  'train/gradients/conv128_layer/conv2d_1/Conv2D_grad/tuple/control_dependency',
#  'train/gradients/conv128_layer/conv2d_1/Conv2D_grad/tuple/control_dependency_1',
#  'train/gradients/conv128_layer/max_pooling2d/MaxPool_grad/MaxPoolGrad',
#  'train/gradients/conv128_layer/conv2d/Relu_grad/ReluGrad',
#  'train/gradients/conv128_layer/conv2d/BiasAdd_grad/BiasAddGrad',
#  'train/gradients/conv128_layer/conv2d/BiasAdd_grad/tuple/group_deps',
#  'train/gradients/conv128_layer/conv2d/BiasAdd_grad/tuple/control_dependency',
#  'train/gradients/conv128_layer/conv2d/BiasAdd_grad/tuple/control_dependency_1',
#  'train/gradients/conv128_layer/conv2d/Conv2D_grad/ShapeN',
#  'train/gradients/conv128_layer/conv2d/Conv2D_grad/Conv2DBackpropInput',
#  'train/gradients/conv128_layer/conv2d/Conv2D_grad/Conv2DBackpropFilter',
#  'train/gradients/conv128_layer/conv2d/Conv2D_grad/tuple/group_deps',
#  'train/gradients/conv128_layer/conv2d/Conv2D_grad/tuple/control_dependency',
#  'train/gradients/conv128_layer/conv2d/Conv2D_grad/tuple/control_dependency_1',
#  'train/gradients/conv64_layer/max_pooling2d/MaxPool_grad/MaxPoolGrad',
#  'train/gradients/conv64_layer/conv2d_1/Relu_grad/ReluGrad',
#  'train/gradients/conv64_layer/conv2d_1/BiasAdd_grad/BiasAddGrad',
#  'train/gradients/conv64_layer/conv2d_1/BiasAdd_grad/tuple/group_deps',
#  'train/gradients/conv64_layer/conv2d_1/BiasAdd_grad/tuple/control_dependency',
#  'train/gradients/conv64_layer/conv2d_1/BiasAdd_grad/tuple/control_dependency_1',
#  'train/gradients/conv64_layer/conv2d_1/Conv2D_grad/ShapeN',
#  'train/gradients/conv64_layer/conv2d_1/Conv2D_grad/Conv2DBackpropInput',
#  'train/gradients/conv64_layer/conv2d_1/Conv2D_grad/Conv2DBackpropFilter',
#  'train/gradients/conv64_layer/conv2d_1/Conv2D_grad/tuple/group_deps',
#  'train/gradients/conv64_layer/conv2d_1/Conv2D_grad/tuple/control_dependency',
#  'train/gradients/conv64_layer/conv2d_1/Conv2D_grad/tuple/control_dependency_1',
#  'train/gradients/conv64_layer/conv2d/Relu_grad/ReluGrad',
#  'train/gradients/conv64_layer/conv2d/BiasAdd_grad/BiasAddGrad',
#  'train/gradients/conv64_layer/conv2d/BiasAdd_grad/tuple/group_deps',
#  'train/gradients/conv64_layer/conv2d/BiasAdd_grad/tuple/control_dependency',
#  'train/gradients/conv64_layer/conv2d/BiasAdd_grad/tuple/control_dependency_1',
#  'train/gradients/conv64_layer/conv2d/Conv2D_grad/ShapeN',
#  'train/gradients/conv64_layer/conv2d/Conv2D_grad/Conv2DBackpropInput',
#  'train/gradients/conv64_layer/conv2d/Conv2D_grad/Conv2DBackpropFilter',
#  'train/gradients/conv64_layer/conv2d/Conv2D_grad/tuple/group_deps',
#  'train/gradients/conv64_layer/conv2d/Conv2D_grad/tuple/control_dependency',
#  'train/gradients/conv64_layer/conv2d/Conv2D_grad/tuple/control_dependency_1',
#  'train/gradients/conv32_layer/max_pooling2d/MaxPool_grad/MaxPoolGrad',
#  'train/gradients/conv32_layer/conv2d/Relu_grad/ReluGrad',
#  'train/gradients/conv32_layer/conv2d/BiasAdd_grad/BiasAddGrad',
#  'train/gradients/conv32_layer/conv2d/BiasAdd_grad/tuple/group_deps',
#  'train/gradients/conv32_layer/conv2d/BiasAdd_grad/tuple/control_dependency',
#  'train/gradients/conv32_layer/conv2d/BiasAdd_grad/tuple/control_dependency_1',
#  'train/gradients/conv32_layer/conv2d/Conv2D_grad/ShapeN',
#  'train/gradients/conv32_layer/conv2d/Conv2D_grad/Conv2DBackpropInput',
#  'train/gradients/conv32_layer/conv2d/Conv2D_grad/Conv2DBackpropFilter',
#  'train/gradients/conv32_layer/conv2d/Conv2D_grad/tuple/group_deps',
#  'train/gradients/conv32_layer/conv2d/Conv2D_grad/tuple/control_dependency',
#  'train/gradients/conv32_layer/conv2d/Conv2D_grad/tuple/control_dependency_1',
#  'train/gradients/conv32_layer/conv32_1/Relu_grad/ReluGrad',
#  'train/gradients/conv32_layer/conv32_1/BiasAdd_grad/BiasAddGrad',
#  'train/gradients/conv32_layer/conv32_1/BiasAdd_grad/tuple/group_deps',
#  'train/gradients/conv32_layer/conv32_1/BiasAdd_grad/tuple/control_dependency',
#  'train/gradients/conv32_layer/conv32_1/BiasAdd_grad/tuple/control_dependency_1',
#  'train/gradients/conv32_layer/conv32_1/Conv2D_grad/ShapeN',
#  'train/gradients/conv32_layer/conv32_1/Conv2D_grad/Conv2DBackpropInput',
#  'train/gradients/conv32_layer/conv32_1/Conv2D_grad/Conv2DBackpropFilter',
#  'train/gradients/conv32_layer/conv32_1/Conv2D_grad/tuple/group_deps',
#  'train/gradients/conv32_layer/conv32_1/Conv2D_grad/tuple/control_dependency',
#  'train/gradients/conv32_layer/conv32_1/Conv2D_grad/tuple/control_dependency_1',
#  'train/beta1_power/initial_value',
#  'train/beta1_power',
#  'train/beta1_power/Assign',
#  'train/beta1_power/read',
#  'train/beta2_power/initial_value',
#  'train/beta2_power',
#  'train/beta2_power/Assign',
#  'train/beta2_power/read',
#  'conv32_1/kernel/Adam/Initializer/zeros',
#  'conv32_1/kernel/Adam',
#  'conv32_1/kernel/Adam/Assign',
#  'conv32_1/kernel/Adam/read',
#  'conv32_1/kernel/Adam_1/Initializer/zeros',
#  'conv32_1/kernel/Adam_1',
#  'conv32_1/kernel/Adam_1/Assign',
#  'conv32_1/kernel/Adam_1/read',
#  'conv32_1/bias/Adam/Initializer/zeros',
#  'conv32_1/bias/Adam',
#  'conv32_1/bias/Adam/Assign',
#  'conv32_1/bias/Adam/read',
#  'conv32_1/bias/Adam_1/Initializer/zeros',
#  'conv32_1/bias/Adam_1',
#  'conv32_1/bias/Adam_1/Assign',
#  'conv32_1/bias/Adam_1/read',
#  'conv2d/kernel/Adam/Initializer/zeros/shape_as_tensor',
#  'conv2d/kernel/Adam/Initializer/zeros/Const',
#  'conv2d/kernel/Adam/Initializer/zeros',
#  'conv2d/kernel/Adam',
#  'conv2d/kernel/Adam/Assign',
#  'conv2d/kernel/Adam/read',
#  'conv2d/kernel/Adam_1/Initializer/zeros/shape_as_tensor',
#  'conv2d/kernel/Adam_1/Initializer/zeros/Const',
#  'conv2d/kernel/Adam_1/Initializer/zeros',
#  'conv2d/kernel/Adam_1',
#  'conv2d/kernel/Adam_1/Assign',
#  'conv2d/kernel/Adam_1/read',
#  'conv2d/bias/Adam/Initializer/zeros',
#  'conv2d/bias/Adam',
#  'conv2d/bias/Adam/Assign',
#  'conv2d/bias/Adam/read',
#  'conv2d/bias/Adam_1/Initializer/zeros',
#  'conv2d/bias/Adam_1',
#  'conv2d/bias/Adam_1/Assign',
#  'conv2d/bias/Adam_1/read',
#  'conv2d_1/kernel/Adam/Initializer/zeros/shape_as_tensor',
#  'conv2d_1/kernel/Adam/Initializer/zeros/Const',
#  'conv2d_1/kernel/Adam/Initializer/zeros',
#  'conv2d_1/kernel/Adam',
#  'conv2d_1/kernel/Adam/Assign',
#  'conv2d_1/kernel/Adam/read',
#  'conv2d_1/kernel/Adam_1/Initializer/zeros/shape_as_tensor',
#  'conv2d_1/kernel/Adam_1/Initializer/zeros/Const',
#  'conv2d_1/kernel/Adam_1/Initializer/zeros',
#  'conv2d_1/kernel/Adam_1',
#  'conv2d_1/kernel/Adam_1/Assign',
#  'conv2d_1/kernel/Adam_1/read',
#  'conv2d_1/bias/Adam/Initializer/zeros',
#  'conv2d_1/bias/Adam',
#  'conv2d_1/bias/Adam/Assign',
#  'conv2d_1/bias/Adam/read',
#  'conv2d_1/bias/Adam_1/Initializer/zeros',
#  'conv2d_1/bias/Adam_1',
#  'conv2d_1/bias/Adam_1/Assign',
#  'conv2d_1/bias/Adam_1/read',
#  'conv2d_2/kernel/Adam/Initializer/zeros/shape_as_tensor',
#  'conv2d_2/kernel/Adam/Initializer/zeros/Const',
#  'conv2d_2/kernel/Adam/Initializer/zeros',
#  'conv2d_2/kernel/Adam',
#  'conv2d_2/kernel/Adam/Assign',
#  'conv2d_2/kernel/Adam/read',
#  'conv2d_2/kernel/Adam_1/Initializer/zeros/shape_as_tensor',
#  'conv2d_2/kernel/Adam_1/Initializer/zeros/Const',
#  'conv2d_2/kernel/Adam_1/Initializer/zeros',
#  'conv2d_2/kernel/Adam_1',
#  'conv2d_2/kernel/Adam_1/Assign',
#  'conv2d_2/kernel/Adam_1/read',
#  'conv2d_2/bias/Adam/Initializer/zeros',
#  'conv2d_2/bias/Adam',
#  'conv2d_2/bias/Adam/Assign',
#  'conv2d_2/bias/Adam/read',
#  'conv2d_2/bias/Adam_1/Initializer/zeros',
#  'conv2d_2/bias/Adam_1',
#  'conv2d_2/bias/Adam_1/Assign',
#  'conv2d_2/bias/Adam_1/read',
#  'conv2d_3/kernel/Adam/Initializer/zeros/shape_as_tensor',
#  'conv2d_3/kernel/Adam/Initializer/zeros/Const',
#  'conv2d_3/kernel/Adam/Initializer/zeros',
#  'conv2d_3/kernel/Adam',
#  'conv2d_3/kernel/Adam/Assign',
#  'conv2d_3/kernel/Adam/read',
#  'conv2d_3/kernel/Adam_1/Initializer/zeros/shape_as_tensor',
#  'conv2d_3/kernel/Adam_1/Initializer/zeros/Const',
#  'conv2d_3/kernel/Adam_1/Initializer/zeros',
#  'conv2d_3/kernel/Adam_1',
#  'conv2d_3/kernel/Adam_1/Assign',
#  'conv2d_3/kernel/Adam_1/read',
#  'conv2d_3/bias/Adam/Initializer/zeros',
#  'conv2d_3/bias/Adam',
#  'conv2d_3/bias/Adam/Assign',
#  'conv2d_3/bias/Adam/read',
#  'conv2d_3/bias/Adam_1/Initializer/zeros',
#  'conv2d_3/bias/Adam_1',
#  'conv2d_3/bias/Adam_1/Assign',
#  'conv2d_3/bias/Adam_1/read',
#  'conv2d_4/kernel/Adam/Initializer/zeros/shape_as_tensor',
#  'conv2d_4/kernel/Adam/Initializer/zeros/Const',
#  'conv2d_4/kernel/Adam/Initializer/zeros',
#  'conv2d_4/kernel/Adam',
#  'conv2d_4/kernel/Adam/Assign',
#  'conv2d_4/kernel/Adam/read',
#  'conv2d_4/kernel/Adam_1/Initializer/zeros/shape_as_tensor',
#  'conv2d_4/kernel/Adam_1/Initializer/zeros/Const',
#  'conv2d_4/kernel/Adam_1/Initializer/zeros',
#  'conv2d_4/kernel/Adam_1',
#  'conv2d_4/kernel/Adam_1/Assign',
#  'conv2d_4/kernel/Adam_1/read',
#  'conv2d_4/bias/Adam/Initializer/zeros',
#  'conv2d_4/bias/Adam',
#  'conv2d_4/bias/Adam/Assign',
#  'conv2d_4/bias/Adam/read',
#  'conv2d_4/bias/Adam_1/Initializer/zeros',
#  'conv2d_4/bias/Adam_1',
#  'conv2d_4/bias/Adam_1/Assign',
#  'conv2d_4/bias/Adam_1/read',
#  'conv2d_5/kernel/Adam/Initializer/zeros/shape_as_tensor',
#  'conv2d_5/kernel/Adam/Initializer/zeros/Const',
#  'conv2d_5/kernel/Adam/Initializer/zeros',
#  'conv2d_5/kernel/Adam',
#  'conv2d_5/kernel/Adam/Assign',
#  'conv2d_5/kernel/Adam/read',
#  'conv2d_5/kernel/Adam_1/Initializer/zeros/shape_as_tensor',
#  'conv2d_5/kernel/Adam_1/Initializer/zeros/Const',
#  'conv2d_5/kernel/Adam_1/Initializer/zeros',
#  'conv2d_5/kernel/Adam_1',
#  'conv2d_5/kernel/Adam_1/Assign',
#  'conv2d_5/kernel/Adam_1/read',
#  'conv2d_5/bias/Adam/Initializer/zeros',
#  'conv2d_5/bias/Adam',
#  'conv2d_5/bias/Adam/Assign',
#  'conv2d_5/bias/Adam/read',
#  'conv2d_5/bias/Adam_1/Initializer/zeros',
#  'conv2d_5/bias/Adam_1',
#  'conv2d_5/bias/Adam_1/Assign',
#  'conv2d_5/bias/Adam_1/read',
#  'dense/kernel/Adam/Initializer/zeros/shape_as_tensor',
#  'dense/kernel/Adam/Initializer/zeros/Const',
#  'dense/kernel/Adam/Initializer/zeros',
#  'dense/kernel/Adam',
#  'dense/kernel/Adam/Assign',
#  'dense/kernel/Adam/read',
#  'dense/kernel/Adam_1/Initializer/zeros/shape_as_tensor',
#  'dense/kernel/Adam_1/Initializer/zeros/Const',
#  'dense/kernel/Adam_1/Initializer/zeros',
#  'dense/kernel/Adam_1',
#  'dense/kernel/Adam_1/Assign',
#  'dense/kernel/Adam_1/read',
#  'dense/bias/Adam/Initializer/zeros',
#  'dense/bias/Adam',
#  'dense/bias/Adam/Assign',
#  'dense/bias/Adam/read',
#  'dense/bias/Adam_1/Initializer/zeros',
#  'dense/bias/Adam_1',
#  'dense/bias/Adam_1/Assign',
#  'dense/bias/Adam_1/read',
#  'dense_1/kernel/Adam/Initializer/zeros/shape_as_tensor',
#  'dense_1/kernel/Adam/Initializer/zeros/Const',
#  'dense_1/kernel/Adam/Initializer/zeros',
#  'dense_1/kernel/Adam',
#  'dense_1/kernel/Adam/Assign',
#  'dense_1/kernel/Adam/read',
#  'dense_1/kernel/Adam_1/Initializer/zeros/shape_as_tensor',
#  'dense_1/kernel/Adam_1/Initializer/zeros/Const',
#  'dense_1/kernel/Adam_1/Initializer/zeros',
#  'dense_1/kernel/Adam_1',
#  'dense_1/kernel/Adam_1/Assign',
#  'dense_1/kernel/Adam_1/read',
#  'dense_1/bias/Adam/Initializer/zeros',
#  'dense_1/bias/Adam',
#  'dense_1/bias/Adam/Assign',
#  'dense_1/bias/Adam/read',
#  'dense_1/bias/Adam_1/Initializer/zeros',
#  'dense_1/bias/Adam_1',
#  'dense_1/bias/Adam_1/Assign',
#  'dense_1/bias/Adam_1/read',
#  'train/Adam/learning_rate',
#  'train/Adam/beta1',
#  'train/Adam/beta2',
#  'train/Adam/epsilon',
#  'train/Adam/update_conv32_1/kernel/ApplyAdam',
#  'train/Adam/update_conv32_1/bias/ApplyAdam',
#  'train/Adam/update_conv2d/kernel/ApplyAdam',
#  'train/Adam/update_conv2d/bias/ApplyAdam',
#  'train/Adam/update_conv2d_1/kernel/ApplyAdam',
#  'train/Adam/update_conv2d_1/bias/ApplyAdam',
#  'train/Adam/update_conv2d_2/kernel/ApplyAdam',
#  'train/Adam/update_conv2d_2/bias/ApplyAdam',
#  'train/Adam/update_conv2d_3/kernel/ApplyAdam',
#  'train/Adam/update_conv2d_3/bias/ApplyAdam',
#  'train/Adam/update_conv2d_4/kernel/ApplyAdam',
#  'train/Adam/update_conv2d_4/bias/ApplyAdam',
#  'train/Adam/update_conv2d_5/kernel/ApplyAdam',
#  'train/Adam/update_conv2d_5/bias/ApplyAdam',
#  'train/Adam/update_dense/kernel/ApplyAdam',
#  'train/Adam/update_dense/bias/ApplyAdam',
#  'train/Adam/update_dense_1/kernel/ApplyAdam',
#  'train/Adam/update_dense_1/bias/ApplyAdam',
#  'train/Adam/mul',
#  'train/Adam/Assign',
#  'train/Adam/mul_1',
#  'train/Adam/Assign_1',
#  'train/Adam',
#  'eval/in_top_k/InTopKV2/k',
#  'eval/in_top_k/InTopKV2',
#  'eval/Cast',
#  'eval/Const',
#  'eval/Mean',
#  'init_and_save/init',
#  'init_and_save/save/Const',
#  'init_and_save/save/SaveV2/tensor_names',
#  'init_and_save/save/SaveV2/shape_and_slices',
#  'init_and_save/save/SaveV2',
#  'init_and_save/save/control_dependency',
#  'init_and_save/save/RestoreV2/tensor_names',
#  'init_and_save/save/RestoreV2/shape_and_slices',
#  'init_and_save/save/RestoreV2',
#  'init_and_save/save/Assign',
#  'init_and_save/save/Assign_1',
#  'init_and_save/save/Assign_2',
#  'init_and_save/save/Assign_3',
#  'init_and_save/save/Assign_4',
#  'init_and_save/save/Assign_5',
#  'init_and_save/save/Assign_6',
#  'init_and_save/save/Assign_7',
#  'init_and_save/save/Assign_8',
#  'init_and_save/save/Assign_9',
#  'init_and_save/save/Assign_10',
#  'init_and_save/save/Assign_11',
#  'init_and_save/save/Assign_12',
#  'init_and_save/save/Assign_13',
#  'init_and_save/save/Assign_14',
#  'init_and_save/save/Assign_15',
#  'init_and_save/save/Assign_16',
#  'init_and_save/save/Assign_17',
#  'init_and_save/save/Assign_18',
#  'init_and_save/save/Assign_19',
#  'init_and_save/save/Assign_20',
#  'init_and_save/save/Assign_21',
#  'init_and_save/save/Assign_22',
#  'init_and_save/save/Assign_23',
#  'init_and_save/save/Assign_24',
#  'init_and_save/save/Assign_25',
#  'init_and_save/save/Assign_26',
#  'init_and_save/save/Assign_27',
#  'init_and_save/save/Assign_28',
#  'init_and_save/save/Assign_29',
#  'init_and_save/save/Assign_30',
#  'init_and_save/save/Assign_31',
#  'init_and_save/save/Assign_32',
#  'init_and_save/save/Assign_33',
#  'init_and_save/save/Assign_34',
#  'init_and_save/save/Assign_35',
#  'init_and_save/save/Assign_36',
#  'init_and_save/save/Assign_37',
#  'init_and_save/save/Assign_38',
#  'init_and_save/save/Assign_39',
#  'init_and_save/save/Assign_40',
#  'init_and_save/save/Assign_41',
#  'init_and_save/save/Assign_42',
#  'init_and_save/save/Assign_43',
#  'init_and_save/save/Assign_44',
#  'init_and_save/save/Assign_45',
#  'init_and_save/save/Assign_46',
#  'init_and_save/save/Assign_47',
#  'init_and_save/save/Assign_48',
#  'init_and_save/save/Assign_49',
#  'init_and_save/save/Assign_50',
#  'init_and_save/save/Assign_51',
#  'init_and_save/save/Assign_52',
#  'init_and_save/save/Assign_53',
#  'init_and_save/save/Assign_54',
#  'init_and_save/save/Assign_55',
#  'init_and_save/save/restore_all',
#  'init',
#  'init_1',
#  'ArgMax/dimension',
#  'ArgMax',
#  'init_2',
#  'ArgMax_1/dimension',
#  'ArgMax_1',
#  'init_3',
#  'ArgMax_2/dimension',
#  'ArgMax_2',
#  'init_4',
#  'ArgMax_3/dimension',
#  'ArgMax_3',
#  'init_5',
#  'ArgMax_4/dimension',
#  'ArgMax_4',
#  'init_6',
#  'ArgMax_5/dimension',
#  'ArgMax_5',
#  'init_7',
#  'ArgMax_6/dimension',
#  'ArgMax_6',
#  'init_8',
#  'ArgMax_7/dimension',
#  'ArgMax_7',
#  'inputs/X_1',
#  'inputs/Reshape/shape_1',
#  'inputs/Reshape_1',
#  'inputs/y_1',
#  'conv32_1/kernel/Initializer/random_uniform/shape_1',
#  'conv32_1/kernel/Initializer/random_uniform/min_1',
#  'conv32_1/kernel/Initializer/random_uniform/max_1',
#  'conv32_1/kernel/Initializer/random_uniform/RandomUniform_1',
#  'conv32_1/kernel/Initializer/random_uniform/sub_1',
#  'conv32_1/kernel/Initializer/random_uniform/mul_1',
#  'conv32_1/kernel/Initializer/random_uniform_1',
#  'conv32_1/kernel_1',
#  'conv32_1/kernel/Assign_1',
#  'conv32_1/kernel/read_1',
#  'conv32_1/bias/Initializer/zeros_1',
#  'conv32_1/bias_1',
#  'conv32_1/bias/Assign_1',
#  'conv32_1/bias/read_1',
#  'conv32_layer/conv32_1/dilation_rate_1',
#  'conv32_layer/conv32_1/Conv2D_1',
#  'conv32_layer/conv32_1/BiasAdd_1',
#  'conv32_layer/conv32_1/Relu_1',
#  'conv2d/kernel/Initializer/random_uniform/shape_1',
#  'conv2d/kernel/Initializer/random_uniform/min_1',
#  'conv2d/kernel/Initializer/random_uniform/max_1',
#  'conv2d/kernel/Initializer/random_uniform/RandomUniform_1',
#  'conv2d/kernel/Initializer/random_uniform/sub_1',
#  'conv2d/kernel/Initializer/random_uniform/mul_1',
#  'conv2d/kernel/Initializer/random_uniform_1',
#  'conv2d/kernel_1',
#  'conv2d/kernel/Assign_1',
#  'conv2d/kernel/read_1',
#  'conv2d/bias/Initializer/zeros_1',
#  'conv2d/bias_1',
#  'conv2d/bias/Assign_1',
#  'conv2d/bias/read_1',
#  'conv32_layer/conv2d/dilation_rate_1',
#  'conv32_layer/conv2d/Conv2D_1',
#  'conv32_layer/conv2d/BiasAdd_1',
#  'conv32_layer/conv2d/Relu_1',
#  'conv32_layer/max_pooling2d/MaxPool_1',
#  'conv32_layer/dropout/Identity_1',
#  'conv2d_1/kernel/Initializer/random_uniform/shape_1',
#  'conv2d_1/kernel/Initializer/random_uniform/min_1',
#  'conv2d_1/kernel/Initializer/random_uniform/max_1',
#  'conv2d_1/kernel/Initializer/random_uniform/RandomUniform_1',
#  'conv2d_1/kernel/Initializer/random_uniform/sub_1',
#  'conv2d_1/kernel/Initializer/random_uniform/mul_1',
#  'conv2d_1/kernel/Initializer/random_uniform_1',
#  'conv2d_1/kernel_1',
#  'conv2d_1/kernel/Assign_1',
#  'conv2d_1/kernel/read_1',
#  'conv2d_1/bias/Initializer/zeros_1',
#  'conv2d_1/bias_1',
#  'conv2d_1/bias/Assign_1',
#  'conv2d_1/bias/read_1',
#  'conv64_layer/conv2d/dilation_rate_1',
#  'conv64_layer/conv2d/Conv2D_1',
#  'conv64_layer/conv2d/BiasAdd_1',
#  'conv64_layer/conv2d/Relu_1',
#  'conv2d_2/kernel/Initializer/random_uniform/shape_1',
#  'conv2d_2/kernel/Initializer/random_uniform/min_1',
#  'conv2d_2/kernel/Initializer/random_uniform/max_1',
#  'conv2d_2/kernel/Initializer/random_uniform/RandomUniform_1',
#  'conv2d_2/kernel/Initializer/random_uniform/sub_1',
#  'conv2d_2/kernel/Initializer/random_uniform/mul_1',
#  'conv2d_2/kernel/Initializer/random_uniform_1',
#  'conv2d_2/kernel_1',
#  'conv2d_2/kernel/Assign_1',
#  'conv2d_2/kernel/read_1',
#  'conv2d_2/bias/Initializer/zeros_1',
#  'conv2d_2/bias_1',
#  'conv2d_2/bias/Assign_1',
#  'conv2d_2/bias/read_1',
#  'conv64_layer/conv2d_1/dilation_rate_1',
#  'conv64_layer/conv2d_1/Conv2D_1',
#  'conv64_layer/conv2d_1/BiasAdd_1',
#  'conv64_layer/conv2d_1/Relu_1',
#  'conv64_layer/max_pooling2d/MaxPool_1',
#  'conv64_layer/dropout/Identity_1',
#  'conv2d_3/kernel/Initializer/random_uniform/shape_1',
#  'conv2d_3/kernel/Initializer/random_uniform/min_1',
#  'conv2d_3/kernel/Initializer/random_uniform/max_1',
#  'conv2d_3/kernel/Initializer/random_uniform/RandomUniform_1',
#  'conv2d_3/kernel/Initializer/random_uniform/sub_1',
#  'conv2d_3/kernel/Initializer/random_uniform/mul_1',
#  'conv2d_3/kernel/Initializer/random_uniform_1',
#  'conv2d_3/kernel_1',
#  'conv2d_3/kernel/Assign_1',
#  'conv2d_3/kernel/read_1',
#  'conv2d_3/bias/Initializer/zeros_1',
#  'conv2d_3/bias_1',
#  'conv2d_3/bias/Assign_1',
#  'conv2d_3/bias/read_1',
#  'conv128_layer/conv2d/dilation_rate_1',
#  'conv128_layer/conv2d/Conv2D_1',
#  'conv128_layer/conv2d/BiasAdd_1',
#  'conv128_layer/conv2d/Relu_1',
#  'conv128_layer/max_pooling2d/MaxPool_1',
#  'conv128_layer/dropout/Identity_1',
#  'conv2d_4/kernel/Initializer/random_uniform/shape_1',
#  'conv2d_4/kernel/Initializer/random_uniform/min_1',
#  'conv2d_4/kernel/Initializer/random_uniform/max_1',
#  'conv2d_4/kernel/Initializer/random_uniform/RandomUniform_1',
#  'conv2d_4/kernel/Initializer/random_uniform/sub_1',
#  'conv2d_4/kernel/Initializer/random_uniform/mul_1',
#  'conv2d_4/kernel/Initializer/random_uniform_1',
#  'conv2d_4/kernel_1',
#  'conv2d_4/kernel/Assign_1',
#  'conv2d_4/kernel/read_1',
#  'conv2d_4/bias/Initializer/zeros_1',
#  'conv2d_4/bias_1',
#  'conv2d_4/bias/Assign_1',
#  'conv2d_4/bias/read_1',
#  'conv128_layer/conv2d_1/dilation_rate_1',
#  'conv128_layer/conv2d_1/Conv2D_1',
#  'conv128_layer/conv2d_1/BiasAdd_1',
#  'conv128_layer/conv2d_1/Relu_1',
#  'conv128_layer/max_pooling2d_1/MaxPool_1',
#  'conv128_layer/dropout_1/Identity_1',
#  'conv2d_5/kernel/Initializer/random_uniform/shape_1',
#  'conv2d_5/kernel/Initializer/random_uniform/min_1',
#  'conv2d_5/kernel/Initializer/random_uniform/max_1',
#  'conv2d_5/kernel/Initializer/random_uniform/RandomUniform_1',
#  'conv2d_5/kernel/Initializer/random_uniform/sub_1',
#  'conv2d_5/kernel/Initializer/random_uniform/mul_1',
#  'conv2d_5/kernel/Initializer/random_uniform_1',
#  'conv2d_5/kernel_1',
#  'conv2d_5/kernel/Assign_1',
#  'conv2d_5/kernel/read_1',
#  'conv2d_5/bias/Initializer/zeros_1',
#  'conv2d_5/bias_1',
#  'conv2d_5/bias/Assign_1',
#  'conv2d_5/bias/read_1',
#  'conv256_layer/conv2d/dilation_rate_1',
#  'conv256_layer/conv2d/Conv2D_1',
#  'conv256_layer/conv2d/BiasAdd_1',
#  'conv256_layer/conv2d/Relu_1',
#  'conv256_layer/max_pooling2d/MaxPool_1',
#  'conv256_layer/dropout/Identity_1',
#  'outputs_layer/flatten/Shape_1',
#  'outputs_layer/flatten/strided_slice/stack_3',
#  'outputs_layer/flatten/strided_slice/stack_1_1',
#  'outputs_layer/flatten/strided_slice/stack_2_1',
#  'outputs_layer/flatten/strided_slice_1',
#  'outputs_layer/flatten/Reshape/shape/1_1',
#  'outputs_layer/flatten/Reshape/shape_1',
#  'outputs_layer/flatten/Reshape_1',
#  'dense/kernel/Initializer/random_uniform/shape_1',
#  'dense/kernel/Initializer/random_uniform/min_1',
#  'dense/kernel/Initializer/random_uniform/max_1',
#  'dense/kernel/Initializer/random_uniform/RandomUniform_1',
#  'dense/kernel/Initializer/random_uniform/sub_1',
#  'dense/kernel/Initializer/random_uniform/mul_1',
#  'dense/kernel/Initializer/random_uniform_1',
#  'dense/kernel_1',
#  'dense/kernel/Assign_1',
#  'dense/kernel/read_1',
#  'dense/bias/Initializer/zeros_1',
#  'dense/bias_1',
#  'dense/bias/Assign_1',
#  'dense/bias/read_1',
#  'outputs_layer/dense/MatMul_1',
#  'outputs_layer/dense/BiasAdd_1',
#  'outputs_layer/dense/Relu_1',
#  'outputs_layer/output/Identity_1',
#  'dense_1/kernel/Initializer/random_uniform/shape_1',
#  'dense_1/kernel/Initializer/random_uniform/min_1',
#  'dense_1/kernel/Initializer/random_uniform/max_1',
#  'dense_1/kernel/Initializer/random_uniform/RandomUniform_1',
#  'dense_1/kernel/Initializer/random_uniform/sub_1',
#  'dense_1/kernel/Initializer/random_uniform/mul_1',
#  'dense_1/kernel/Initializer/random_uniform_1',
#  'dense_1/kernel_1',
#  'dense_1/kernel/Assign_1',
#  'dense_1/kernel/read_1',
#  'dense_1/bias/Initializer/zeros_1',
#  'dense_1/bias_1',
#  'dense_1/bias/Assign_1',
#  'dense_1/bias/read_1',
#  'outputs_layer/dense_1/MatMul_1',
#  'outputs_layer/dense_1/BiasAdd_1',
#  'outputs_layer/dense_1/Relu_1',
#  'outputs_layer/Y_proba_1',
#  'train/SparseSoftmaxCrossEntropyWithLogits/Shape_1',
#  'train/SparseSoftmaxCrossEntropyWithLogits/SparseSoftmaxCrossEntropyWithLogits_1',
#  'train/Const_1',
#  'train/Mean_1',
#  'train/gradients/Shape_1',
#  'train/gradients/grad_ys_0_1',
#  'train/gradients/Fill_1',
#  'train/gradients/train/Mean_grad/Reshape/shape_1',
#  'train/gradients/train/Mean_grad/Reshape_1',
#  'train/gradients/train/Mean_grad/Shape_3',
#  'train/gradients/train/Mean_grad/Tile_1',
#  'train/gradients/train/Mean_grad/Shape_1_1',
#  'train/gradients/train/Mean_grad/Shape_2_1',
#  'train/gradients/train/Mean_grad/Const_2',
#  'train/gradients/train/Mean_grad/Prod_2',
#  'train/gradients/train/Mean_grad/Const_1_1',
#  'train/gradients/train/Mean_grad/Prod_1_1',
#  'train/gradients/train/Mean_grad/Maximum/y_1',
#  'train/gradients/train/Mean_grad/Maximum_1',
#  'train/gradients/train/Mean_grad/floordiv_1',
#  'train/gradients/train/Mean_grad/Cast_1',
#  'train/gradients/train/Mean_grad/truediv_1',
#  'train/gradients/zeros_like_1',
#  'train/gradients/train/SparseSoftmaxCrossEntropyWithLogits/SparseSoftmaxCrossEntropyWithLogits_grad/PreventGradient_1',
#  'train/gradients/train/SparseSoftmaxCrossEntropyWithLogits/SparseSoftmaxCrossEntropyWithLogits_grad/ExpandDims/dim_1',
#  'train/gradients/train/SparseSoftmaxCrossEntropyWithLogits/SparseSoftmaxCrossEntropyWithLogits_grad/ExpandDims_1',
#  'train/gradients/train/SparseSoftmaxCrossEntropyWithLogits/SparseSoftmaxCrossEntropyWithLogits_grad/mul_1',
#  'train/gradients/outputs_layer/dense_1/Relu_grad/ReluGrad_1',
#  'train/gradients/outputs_layer/dense_1/BiasAdd_grad/BiasAddGrad_1',
#  'train/gradients/outputs_layer/dense_1/BiasAdd_grad/tuple/group_deps_1',
#  'train/gradients/outputs_layer/dense_1/BiasAdd_grad/tuple/control_dependency_2',
#  'train/gradients/outputs_layer/dense_1/BiasAdd_grad/tuple/control_dependency_1_1',
#  'train/gradients/outputs_layer/dense_1/MatMul_grad/MatMul_2',
#  'train/gradients/outputs_layer/dense_1/MatMul_grad/MatMul_1_1',
#  'train/gradients/outputs_layer/dense_1/MatMul_grad/tuple/group_deps_1',
#  'train/gradients/outputs_layer/dense_1/MatMul_grad/tuple/control_dependency_2',
#  'train/gradients/outputs_layer/dense_1/MatMul_grad/tuple/control_dependency_1_1',
#  'train/gradients/outputs_layer/dense/Relu_grad/ReluGrad_1',
#  'train/gradients/outputs_layer/dense/BiasAdd_grad/BiasAddGrad_1',
#  'train/gradients/outputs_layer/dense/BiasAdd_grad/tuple/group_deps_1',
#  'train/gradients/outputs_layer/dense/BiasAdd_grad/tuple/control_dependency_2',
#  'train/gradients/outputs_layer/dense/BiasAdd_grad/tuple/control_dependency_1_1',
#  'train/gradients/outputs_layer/dense/MatMul_grad/MatMul_2',
#  'train/gradients/outputs_layer/dense/MatMul_grad/MatMul_1_1',
#  'train/gradients/outputs_layer/dense/MatMul_grad/tuple/group_deps_1',
#  'train/gradients/outputs_layer/dense/MatMul_grad/tuple/control_dependency_2',
#  'train/gradients/outputs_layer/dense/MatMul_grad/tuple/control_dependency_1_1',
#  'train/gradients/outputs_layer/flatten/Reshape_grad/Shape_1',
#  'train/gradients/outputs_layer/flatten/Reshape_grad/Reshape_1',
#  'train/gradients/conv256_layer/max_pooling2d/MaxPool_grad/MaxPoolGrad_1',
#  'train/gradients/conv256_layer/conv2d/Relu_grad/ReluGrad_1',
#  'train/gradients/conv256_layer/conv2d/BiasAdd_grad/BiasAddGrad_1',
#  'train/gradients/conv256_layer/conv2d/BiasAdd_grad/tuple/group_deps_1',
#  'train/gradients/conv256_layer/conv2d/BiasAdd_grad/tuple/control_dependency_2',
#  'train/gradients/conv256_layer/conv2d/BiasAdd_grad/tuple/control_dependency_1_1',
#  'train/gradients/conv256_layer/conv2d/Conv2D_grad/ShapeN_1',
#  'train/gradients/conv256_layer/conv2d/Conv2D_grad/Conv2DBackpropInput_1',
#  'train/gradients/conv256_layer/conv2d/Conv2D_grad/Conv2DBackpropFilter_1',
#  'train/gradients/conv256_layer/conv2d/Conv2D_grad/tuple/group_deps_1',
#  'train/gradients/conv256_layer/conv2d/Conv2D_grad/tuple/control_dependency_2',
#  'train/gradients/conv256_layer/conv2d/Conv2D_grad/tuple/control_dependency_1_1',
#  'train/gradients/conv128_layer/max_pooling2d_1/MaxPool_grad/MaxPoolGrad_1',
#  'train/gradients/conv128_layer/conv2d_1/Relu_grad/ReluGrad_1',
#  'train/gradients/conv128_layer/conv2d_1/BiasAdd_grad/BiasAddGrad_1',
#  'train/gradients/conv128_layer/conv2d_1/BiasAdd_grad/tuple/group_deps_1',
#  'train/gradients/conv128_layer/conv2d_1/BiasAdd_grad/tuple/control_dependency_2',
#  'train/gradients/conv128_layer/conv2d_1/BiasAdd_grad/tuple/control_dependency_1_1',
#  'train/gradients/conv128_layer/conv2d_1/Conv2D_grad/ShapeN_1',
#  'train/gradients/conv128_layer/conv2d_1/Conv2D_grad/Conv2DBackpropInput_1',
#  'train/gradients/conv128_layer/conv2d_1/Conv2D_grad/Conv2DBackpropFilter_1',
#  'train/gradients/conv128_layer/conv2d_1/Conv2D_grad/tuple/group_deps_1',
#  'train/gradients/conv128_layer/conv2d_1/Conv2D_grad/tuple/control_dependency_2',
#  'train/gradients/conv128_layer/conv2d_1/Conv2D_grad/tuple/control_dependency_1_1',
#  'train/gradients/conv128_layer/max_pooling2d/MaxPool_grad/MaxPoolGrad_1',
#  'train/gradients/conv128_layer/conv2d/Relu_grad/ReluGrad_1',
#  'train/gradients/conv128_layer/conv2d/BiasAdd_grad/BiasAddGrad_1',
#  'train/gradients/conv128_layer/conv2d/BiasAdd_grad/tuple/group_deps_1',
#  'train/gradients/conv128_layer/conv2d/BiasAdd_grad/tuple/control_dependency_2',
#  'train/gradients/conv128_layer/conv2d/BiasAdd_grad/tuple/control_dependency_1_1',
#  'train/gradients/conv128_layer/conv2d/Conv2D_grad/ShapeN_1',
#  'train/gradients/conv128_layer/conv2d/Conv2D_grad/Conv2DBackpropInput_1',
#  'train/gradients/conv128_layer/conv2d/Conv2D_grad/Conv2DBackpropFilter_1',
#  'train/gradients/conv128_layer/conv2d/Conv2D_grad/tuple/group_deps_1',
#  'train/gradients/conv128_layer/conv2d/Conv2D_grad/tuple/control_dependency_2',
#  'train/gradients/conv128_layer/conv2d/Conv2D_grad/tuple/control_dependency_1_1',
#  'train/gradients/conv64_layer/max_pooling2d/MaxPool_grad/MaxPoolGrad_1',
#  'train/gradients/conv64_layer/conv2d_1/Relu_grad/ReluGrad_1',
#  'train/gradients/conv64_layer/conv2d_1/BiasAdd_grad/BiasAddGrad_1',
#  'train/gradients/conv64_layer/conv2d_1/BiasAdd_grad/tuple/group_deps_1',
#  'train/gradients/conv64_layer/conv2d_1/BiasAdd_grad/tuple/control_dependency_2',
#  'train/gradients/conv64_layer/conv2d_1/BiasAdd_grad/tuple/control_dependency_1_1',
#  'train/gradients/conv64_layer/conv2d_1/Conv2D_grad/ShapeN_1',
#  'train/gradients/conv64_layer/conv2d_1/Conv2D_grad/Conv2DBackpropInput_1',
#  'train/gradients/conv64_layer/conv2d_1/Conv2D_grad/Conv2DBackpropFilter_1',
#  'train/gradients/conv64_layer/conv2d_1/Conv2D_grad/tuple/group_deps_1',
#  'train/gradients/conv64_layer/conv2d_1/Conv2D_grad/tuple/control_dependency_2',
#  'train/gradients/conv64_layer/conv2d_1/Conv2D_grad/tuple/control_dependency_1_1',
#  'train/gradients/conv64_layer/conv2d/Relu_grad/ReluGrad_1',
#  'train/gradients/conv64_layer/conv2d/BiasAdd_grad/BiasAddGrad_1',
#  'train/gradients/conv64_layer/conv2d/BiasAdd_grad/tuple/group_deps_1',
#  'train/gradients/conv64_layer/conv2d/BiasAdd_grad/tuple/control_dependency_2',
#  'train/gradients/conv64_layer/conv2d/BiasAdd_grad/tuple/control_dependency_1_1',
#  'train/gradients/conv64_layer/conv2d/Conv2D_grad/ShapeN_1',
#  'train/gradients/conv64_layer/conv2d/Conv2D_grad/Conv2DBackpropInput_1',
#  'train/gradients/conv64_layer/conv2d/Conv2D_grad/Conv2DBackpropFilter_1',
#  'train/gradients/conv64_layer/conv2d/Conv2D_grad/tuple/group_deps_1',
#  'train/gradients/conv64_layer/conv2d/Conv2D_grad/tuple/control_dependency_2',
#  'train/gradients/conv64_layer/conv2d/Conv2D_grad/tuple/control_dependency_1_1',
#  'train/gradients/conv32_layer/max_pooling2d/MaxPool_grad/MaxPoolGrad_1',
#  'train/gradients/conv32_layer/conv2d/Relu_grad/ReluGrad_1',
#  'train/gradients/conv32_layer/conv2d/BiasAdd_grad/BiasAddGrad_1',
#  'train/gradients/conv32_layer/conv2d/BiasAdd_grad/tuple/group_deps_1',
#  'train/gradients/conv32_layer/conv2d/BiasAdd_grad/tuple/control_dependency_2',
#  'train/gradients/conv32_layer/conv2d/BiasAdd_grad/tuple/control_dependency_1_1',
#  'train/gradients/conv32_layer/conv2d/Conv2D_grad/ShapeN_1',
#  'train/gradients/conv32_layer/conv2d/Conv2D_grad/Conv2DBackpropInput_1',
#  'train/gradients/conv32_layer/conv2d/Conv2D_grad/Conv2DBackpropFilter_1',
#  'train/gradients/conv32_layer/conv2d/Conv2D_grad/tuple/group_deps_1',
#  'train/gradients/conv32_layer/conv2d/Conv2D_grad/tuple/control_dependency_2',
#  'train/gradients/conv32_layer/conv2d/Conv2D_grad/tuple/control_dependency_1_1',
#  'train/gradients/conv32_layer/conv32_1/Relu_grad/ReluGrad_1',
#  'train/gradients/conv32_layer/conv32_1/BiasAdd_grad/BiasAddGrad_1',
#  'train/gradients/conv32_layer/conv32_1/BiasAdd_grad/tuple/group_deps_1',
#  'train/gradients/conv32_layer/conv32_1/BiasAdd_grad/tuple/control_dependency_2',
#  'train/gradients/conv32_layer/conv32_1/BiasAdd_grad/tuple/control_dependency_1_1',
#  'train/gradients/conv32_layer/conv32_1/Conv2D_grad/ShapeN_1',
#  'train/gradients/conv32_layer/conv32_1/Conv2D_grad/Conv2DBackpropInput_1',
#  'train/gradients/conv32_layer/conv32_1/Conv2D_grad/Conv2DBackpropFilter_1',
#  'train/gradients/conv32_layer/conv32_1/Conv2D_grad/tuple/group_deps_1',
#  'train/gradients/conv32_layer/conv32_1/Conv2D_grad/tuple/control_dependency_2',
#  'train/gradients/conv32_layer/conv32_1/Conv2D_grad/tuple/control_dependency_1_1',
#  'train/beta1_power/initial_value_1',
#  'train/beta1_power_1',
#  'train/beta1_power/Assign_1',
#  'train/beta1_power/read_1',
#  'train/beta2_power/initial_value_1',
#  'train/beta2_power_1',
#  'train/beta2_power/Assign_1',
#  'train/beta2_power/read_1',
#  'conv32_1/kernel/Adam/Initializer/zeros_1',
#  'conv32_1/kernel/Adam_2',
#  'conv32_1/kernel/Adam/Assign_1',
#  'conv32_1/kernel/Adam/read_1',
#  'conv32_1/kernel/Adam_1/Initializer/zeros_1',
#  'conv32_1/kernel/Adam_1_1',
#  'conv32_1/kernel/Adam_1/Assign_1',
#  'conv32_1/kernel/Adam_1/read_1',
#  'conv32_1/bias/Adam/Initializer/zeros_1',
#  'conv32_1/bias/Adam_2',
#  'conv32_1/bias/Adam/Assign_1',
#  'conv32_1/bias/Adam/read_1',
#  'conv32_1/bias/Adam_1/Initializer/zeros_1',
#  'conv32_1/bias/Adam_1_1',
#  'conv32_1/bias/Adam_1/Assign_1',
#  'conv32_1/bias/Adam_1/read_1',
#  'conv2d/kernel/Adam/Initializer/zeros/shape_as_tensor_1',
#  'conv2d/kernel/Adam/Initializer/zeros/Const_1',
#  'conv2d/kernel/Adam/Initializer/zeros_1',
#  'conv2d/kernel/Adam_2',
#  'conv2d/kernel/Adam/Assign_1',
#  'conv2d/kernel/Adam/read_1',
#  'conv2d/kernel/Adam_1/Initializer/zeros/shape_as_tensor_1',
#  'conv2d/kernel/Adam_1/Initializer/zeros/Const_1',
#  'conv2d/kernel/Adam_1/Initializer/zeros_1',
#  'conv2d/kernel/Adam_1_1',
#  'conv2d/kernel/Adam_1/Assign_1',
#  'conv2d/kernel/Adam_1/read_1',
#  'conv2d/bias/Adam/Initializer/zeros_1',
#  'conv2d/bias/Adam_2',
#  'conv2d/bias/Adam/Assign_1',
#  'conv2d/bias/Adam/read_1',
#  'conv2d/bias/Adam_1/Initializer/zeros_1',
#  'conv2d/bias/Adam_1_1',
#  'conv2d/bias/Adam_1/Assign_1',
#  'conv2d/bias/Adam_1/read_1',
#  'conv2d_1/kernel/Adam/Initializer/zeros/shape_as_tensor_1',
#  'conv2d_1/kernel/Adam/Initializer/zeros/Const_1',
#  'conv2d_1/kernel/Adam/Initializer/zeros_1',
#  'conv2d_1/kernel/Adam_2',
#  'conv2d_1/kernel/Adam/Assign_1',
#  'conv2d_1/kernel/Adam/read_1',
#  'conv2d_1/kernel/Adam_1/Initializer/zeros/shape_as_tensor_1',
#  'conv2d_1/kernel/Adam_1/Initializer/zeros/Const_1',
#  'conv2d_1/kernel/Adam_1/Initializer/zeros_1',
#  'conv2d_1/kernel/Adam_1_1',
#  'conv2d_1/kernel/Adam_1/Assign_1',
#  'conv2d_1/kernel/Adam_1/read_1',
#  'conv2d_1/bias/Adam/Initializer/zeros_1',
#  'conv2d_1/bias/Adam_2',
#  'conv2d_1/bias/Adam/Assign_1',
#  'conv2d_1/bias/Adam/read_1',
#  'conv2d_1/bias/Adam_1/Initializer/zeros_1',
#  'conv2d_1/bias/Adam_1_1',
#  'conv2d_1/bias/Adam_1/Assign_1',
#  ...]

# %%
type(y_train[20])
# Out:
# numpy.int64
